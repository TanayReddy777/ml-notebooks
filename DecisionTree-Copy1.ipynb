# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
df = pd.read_csv(r"C:\Users\tanay\OneDrive\Desktop\datasets\Purchase_new.csv")

# %%
df
# Out:
#    Holiday Discount Free Delivery Purchase
# 0       No      Yes           Yes      Yes
# 1       No      Yes           Yes      Yes
# 2       No       No            No       No
# 3      yes      Yes           Yes      Yes
# 4      yes      Yes           Yes      Yes
# 5      yes       No            No       No
# 6      yes      Yes            No      Yes
# 7       No      Yes           Yes      Yes
# 8      yes      Yes           Yes      Yes
# 9      yes      Yes           Yes      Yes
# 10     yes       No           Yes      Yes
# 11     yes       No            No       No
# 12     yes      Yes           Yes      Yes
# 13     yes      Yes           Yes      Yes
# 14     yes      Yes           Yes      Yes
# 15      No      Yes           Yes      Yes
# 16     yes       No           Yes      Yes
# 17      No      Yes            No      Yes
# 18     yes       No            No      Yes
# 19     yes       No           Yes      Yes
# 20      No      Yes           Yes      Yes
# 21     yes      Yes           Yes       No
# 22     yes       No           Yes      Yes
# 23      No      Yes           Yes      Yes
# 24     yes       No            No       No
# 25      No       No           Yes       No
# 26      No      Yes           Yes      Yes
# 27      No      Yes           Yes      Yes
# 28     yes      Yes           Yes      Yes
# 29     yes      Yes           Yes      Yes

# %%
df.isnull().sum()
# Out:
# Holiday          0
# Discount         0
# Free Delivery    0
# Purchase         0
# dtype: int64

# %%
x = df.drop("Purchase",axis=1)
y = df["Purchase"]

# %%
print(x.shape)
print(y.shape)
# Out:
# (30, 3)
# (30,)

# %%
x = pd.get_dummies(x,columns = ["Holiday","Discount","Free Delivery"],drop_first=True)

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
x.head()
# Out:
#    Holiday_yes  Discount_Yes  Free Delivery_Yes
# 0        False          True               True
# 1        False          True               True
# 2        False         False              False
# 3         True          True               True
# 4         True          True               True

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 42,test_size = 0.1)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
dt = DecisionTreeClassifier(random_state = 42)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = dt.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1])

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

# %%
print("Accuracy: ",accuracy_score(y_test,y_pred))
print("Precision Score: ",precision_score(y_test,y_pred))
print("Recall score: ",recall_score(y_test,y_pred))
# Out:
# Accuracy:  1.0
# Precision Score:  1.0
# Recall score:  1.0

# %%
param_grid = {
    'criterion' : ['gini','entropy'],
    'min_samples_split' : [2,4],
    'min_samples_leaf' : [1,2,4],
    'max_depth' : [1,2,4]
}

# %%
gs = GridSearchCV(
    estimator = DecisionTreeClassifier(),
    cv = 5,
    param_grid = param_grid,
    n_jobs = -1,
    scoring = 'accuracy'
)

# %%
gs.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 4], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 4]},
#              scoring='accuracy')

# %%
print(gs.best_params_)
print(gs.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.8800000000000001

# %%
plt.figure(figsize=(12,8))
plot_tree(
    dt,
    feature_names=x.columns,   
    filled=True,
    rounded=True,
    fontsize=10
)
plt.show()
